# %%
import geopandas as gpd

# Load your GeoJSON file into a GeoDataFrame
geojson_file_path = "../datasets/LAPD_Division.geojson"
geo_df = gpd.read_file(geojson_file_path)

# Select the relevant columns
geo_data = geo_df[['PREC', 'PERIMETER', 'AREA']]
geo_data.columns = ['area', 'perimeter', 'area_size']
geo_data['perimeter'] = geo_data['perimeter'] / 1_000
geo_data['area_size'] = geo_data['area_size'] / 10_000_000

import pandas as pd

# Merge `df` with `geo_data` based on the 'area' and 'AREA'
# merged_df = df.merge(geo_data, how='inner', left_on='area', right_on='AREA')

# Now `merged_df` contains the merged data
geo_data
# Out:
# C:\Users\gemj9\AppData\Local\Temp\ipykernel_34316\2970676316.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   geo_data['perimeter'] = geo_data['perimeter'] / 1_000
# C:\Users\gemj9\AppData\Local\Temp\ipykernel_34316\2970676316.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   geo_data['area_size'] = geo_data['area_size'] / 10_000_000
#     area   perimeter   area_size
# 0     19  190.817496   69.958261
# 1     17  175.591703  134.681637
# 2     16  203.717879  129.738455
# ...
